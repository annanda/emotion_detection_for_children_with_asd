# %%
from scipy.io import arff
import pandas as pd
import numpy as np

# Loading the testing data into pandas
data_train = arff.loadarff('features/video/AU/train_1_3.0_0.4.arff')
data_train = pd.DataFrame(data_train[0])
data_train
# Out:
#      frametime  AU01_r_mean  AU02_r_mean  AU04_r_mean  AU05_r_mean  \
# 0          0.0     0.106990          0.0     0.025586     0.017015
# 1          0.4     0.069754          0.0     0.029648     0.019715
# 2          0.8     0.002540          0.0     0.035241     0.023435
# 3          1.2     0.000000          0.0     0.043437     0.028885
# 4          1.6     0.000000          0.0     0.056600     0.037638
# ..         ...          ...          ...          ...          ...
# 746      298.4          NaN          NaN          NaN          NaN
# 747      298.8          NaN          NaN          NaN          NaN
# 748      299.2          NaN          NaN          NaN          NaN
# 749      299.6          NaN          NaN          NaN          NaN
# 750      300.0          NaN          NaN          NaN          NaN
#
#      AU06_r_mean  AU07_r_mean  AU09_r_mean  AU10_r_mean  AU12_r_mean  ...  \
# 0         1.6269       1.1688      0.34401       1.1969       1.0471  ...
# 1         1.7723       1.2874      0.39672       1.2833       1.2055  ...
# 2         1.8912       1.3600      0.46930       1.3793       1.3525  ...
# 3         1.9639       1.4077      0.55417       1.4234       1.4557  ...
# 4         2.0157       1.4732      0.61232       1.4870       1.5672  ...
# ..           ...          ...          ...          ...          ...  ...
# 746          NaN          NaN          NaN          NaN          NaN  ...
# 747          NaN          NaN          NaN          NaN          NaN  ...
# 748          NaN          NaN          NaN          NaN          NaN  ...
# 749          NaN          NaN          NaN          NaN          NaN  ...
# 750          NaN          NaN          NaN          NaN          NaN  ...
#
#      AU10_r_std  AU12_r_std  AU14_r_std  AU15_r_std  AU17_r_std  AU20_r_std  \
# 0       0.41313     0.64237     0.35901     0.14949     0.57717     0.11262
# 1       0.37360     0.54111     0.28882     0.15247     0.60335     0.11909
# 2       0.31706     0.44681     0.27850     0.16391     0.57446     0.12654
# 3       0.33058     0.43409     0.28706     0.18108     0.58228     0.13489
# 4       0.34367     0.43803     0.30839     0.20503     0.65853     0.14299
# ..          ...         ...         ...         ...         ...         ...
# 746         NaN         NaN         NaN         NaN         NaN         NaN
# 747         NaN         NaN         NaN         NaN         NaN         NaN
# 748         NaN         NaN         NaN         NaN         NaN         NaN
# 749         NaN         NaN         NaN         NaN         NaN         NaN
# 750         NaN         NaN         NaN         NaN         NaN         NaN
#
#      AU23_r_std  AU25_r_std  AU26_r_std  AU45_r_std
# 0       0.38203     0.78689     0.22132    0.079360
# 1       0.41000     0.83146     0.21288    0.085122
# 2       0.44515     0.88307     0.15062    0.092345
# 3       0.49113     0.92663     0.14982    0.101760
# 4       0.55580     0.96186     0.16680    0.114740
# ..          ...         ...         ...         ...
# 746         NaN         NaN         NaN         NaN
# 747         NaN         NaN         NaN         NaN
# 748         NaN         NaN         NaN         NaN
# 749         NaN         NaN         NaN         NaN
# 750         NaN         NaN         NaN         NaN
#
# [751 rows x 35 columns]

# %%
# loading label data

# import arff 

data_label = arff.loadarff('dev_1.arff')
data_label = pd.DataFrame(data_label[0])
data_label
# Out:
#       frametime  GoldStandard
# 0          0.00     -0.022925
# 1          0.04     -0.022925
# 2          0.08     -0.022925
# 3          0.12     -0.022925
# 4          0.16     -0.022925
# ...         ...           ...
# 7496     299.84     -0.109591
# 7497     299.88     -0.111258
# 7498     299.92     -0.107925
# 7499     299.96     -0.112925
# 7500     300.00     -0.117925
#
# [7501 rows x 2 columns]

# %%
data_train.merge(data_label, how='left', on='frametime')
# Out:
#      frametime  AU01_r_mean  AU02_r_mean  AU04_r_mean  AU05_r_mean  \
# 0          0.0     0.106990          0.0     0.025586     0.017015
# 1          0.4     0.069754          0.0     0.029648     0.019715
# 2          0.8     0.002540          0.0     0.035241     0.023435
# 3          1.2     0.000000          0.0     0.043437     0.028885
# 4          1.6     0.000000          0.0     0.056600     0.037638
# ..         ...          ...          ...          ...          ...
# 746      298.4          NaN          NaN          NaN          NaN
# 747      298.8          NaN          NaN          NaN          NaN
# 748      299.2          NaN          NaN          NaN          NaN
# 749      299.6          NaN          NaN          NaN          NaN
# 750      300.0          NaN          NaN          NaN          NaN
#
#      AU06_r_mean  AU07_r_mean  AU09_r_mean  AU10_r_mean  AU12_r_mean  ...  \
# 0         1.6269       1.1688      0.34401       1.1969       1.0471  ...
# 1         1.7723       1.2874      0.39672       1.2833       1.2055  ...
# 2         1.8912       1.3600      0.46930       1.3793       1.3525  ...
# 3         1.9639       1.4077      0.55417       1.4234       1.4557  ...
# 4         2.0157       1.4732      0.61232       1.4870       1.5672  ...
# ..           ...          ...          ...          ...          ...  ...
# 746          NaN          NaN          NaN          NaN          NaN  ...
# 747          NaN          NaN          NaN          NaN          NaN  ...
# 748          NaN          NaN          NaN          NaN          NaN  ...
# 749          NaN          NaN          NaN          NaN          NaN  ...
# 750          NaN          NaN          NaN          NaN          NaN  ...
#
#      AU12_r_std  AU14_r_std  AU15_r_std  AU17_r_std  AU20_r_std  AU23_r_std  \
# 0       0.64237     0.35901     0.14949     0.57717     0.11262     0.38203
# 1       0.54111     0.28882     0.15247     0.60335     0.11909     0.41000
# 2       0.44681     0.27850     0.16391     0.57446     0.12654     0.44515
# 3       0.43409     0.28706     0.18108     0.58228     0.13489     0.49113
# 4       0.43803     0.30839     0.20503     0.65853     0.14299     0.55580
# ..          ...         ...         ...         ...         ...         ...
# 746         NaN         NaN         NaN         NaN         NaN         NaN
# 747         NaN         NaN         NaN         NaN         NaN         NaN
# 748         NaN         NaN         NaN         NaN         NaN         NaN
# 749         NaN         NaN         NaN         NaN         NaN         NaN
# 750         NaN         NaN         NaN         NaN         NaN         NaN
#
#      AU25_r_std  AU26_r_std  AU45_r_std  GoldStandard
# 0       0.78689     0.22132    0.079360     -0.022925
# 1       0.83146     0.21288    0.085122     -0.022925
# 2       0.88307     0.15062    0.092345     -0.007925
# 3       0.92663     0.14982    0.101760      0.007075
# 4       0.96186     0.16680    0.114740      0.010408
# ..          ...         ...         ...           ...
# 746         NaN         NaN         NaN     -0.159591
# 747         NaN         NaN         NaN     -0.184591
# 748         NaN         NaN         NaN     -0.191258
# 749         NaN         NaN         NaN     -0.122925
# 750         NaN         NaN         NaN     -0.117925
#
# [751 rows x 36 columns]

# %%
data_train.merge(data_label, how='right', on='frametime')
# Out:
#       frametime  AU01_r_mean  AU02_r_mean  AU04_r_mean  AU05_r_mean  \
# 0          0.00     0.106990          0.0     0.025586     0.017015
# 1          0.40     0.069754          0.0     0.029648     0.019715
# 2          0.80     0.002540          0.0     0.035241     0.023435
# 3          1.20     0.000000          0.0     0.043437     0.028885
# 4          1.60     0.000000          0.0     0.056600     0.037638
# ...         ...          ...          ...          ...          ...
# 7496     299.80          NaN          NaN          NaN          NaN
# 7497     299.84          NaN          NaN          NaN          NaN
# 7498     299.88          NaN          NaN          NaN          NaN
# 7499     299.92          NaN          NaN          NaN          NaN
# 7500     299.96          NaN          NaN          NaN          NaN
#
#       AU06_r_mean  AU07_r_mean  AU09_r_mean  AU10_r_mean  AU12_r_mean  ...  \
# 0          1.6269       1.1688      0.34401       1.1969       1.0471  ...
# 1          1.7723       1.2874      0.39672       1.2833       1.2055  ...
# 2          1.8912       1.3600      0.46930       1.3793       1.3525  ...
# 3          1.9639       1.4077      0.55417       1.4234       1.4557  ...
# 4          2.0157       1.4732      0.61232       1.4870       1.5672  ...
# ...           ...          ...          ...          ...          ...  ...
# 7496          NaN          NaN          NaN          NaN          NaN  ...
# 7497          NaN          NaN          NaN          NaN          NaN  ...
# 7498          NaN          NaN          NaN          NaN          NaN  ...
# 7499          NaN          NaN          NaN          NaN          NaN  ...
# 7500          NaN          NaN          NaN          NaN          NaN  ...
#
#       AU12_r_std  AU14_r_std  AU15_r_std  AU17_r_std  AU20_r_std  AU23_r_std  \
# 0        0.64237     0.35901     0.14949     0.57717     0.11262     0.38203
# 1        0.54111     0.28882     0.15247     0.60335     0.11909     0.41000
# 2        0.44681     0.27850     0.16391     0.57446     0.12654     0.44515
# 3        0.43409     0.28706     0.18108     0.58228     0.13489     0.49113
# 4        0.43803     0.30839     0.20503     0.65853     0.14299     0.55580
# ...          ...         ...         ...         ...         ...         ...
# 7496         NaN         NaN         NaN         NaN         NaN         NaN
# 7497         NaN         NaN         NaN         NaN         NaN         NaN
# 7498         NaN         NaN         NaN         NaN         NaN         NaN
# 7499         NaN         NaN         NaN         NaN         NaN         NaN
# 7500         NaN         NaN         NaN         NaN         NaN         NaN
#
#       AU25_r_std  AU26_r_std  AU45_r_std  GoldStandard
# 0        0.78689     0.22132    0.079360     -0.022925
# 1        0.83146     0.21288    0.085122     -0.022925
# 2        0.88307     0.15062    0.092345     -0.007925
# 3        0.92663     0.14982    0.101760      0.007075
# 4        0.96186     0.16680    0.114740      0.010408
# ...          ...         ...         ...           ...
# 7496         NaN         NaN         NaN     -0.109591
# 7497         NaN         NaN         NaN     -0.109591
# 7498         NaN         NaN         NaN     -0.111258
# 7499         NaN         NaN         NaN     -0.107925
# 7500         NaN         NaN         NaN     -0.112925
#
# [7501 rows x 36 columns]

# %%
from scipy.io import arff
import pandas as pd

# Loading the testing data into pandas
data_train = arff.loadarff('features/video/AU/train_1_3.0_0.4.arff')
data_train = pd.DataFrame(data_train[0])
# print(data_train)

data_label = arff.loadarff('labels/arousal/train_1.arff')
data_label = pd.DataFrame(data_label[0])
# print(data_label)

data_label_valence = arff.loadarff('labels/valence/train_1.arff')
data_label_valence = pd.DataFrame(data_label_valence[0])
# print(data_label_valence)

# # merged features + annotation by frametime arousal
# merged = data_train.merge(data_label, how='left', on='frametime')
# print(merged)
#
# #  merged features + annotation arousal/valence
# merged_total = merged.merge(data_label_valence, how='left', on='frametime')
# print(merged_total)

# merged dataset of annotation - arousal/valence
merged_annotation = data_label.merge(data_label_valence, how='left', on='frametime')
# print(merged_annotation)

# merged features + annotation by frametime
merged = data_train.merge(merged_annotation, how='left', on='frametime')
# to see statistics of the dataset
merged.describe()
# Out:
#         frametime  AU01_r_mean  AU02_r_mean  AU04_r_mean  AU05_r_mean  \
# count  751.000000   616.000000   616.000000   616.000000   616.000000
# mean   150.000000     1.005402     0.178804     0.287059     0.089161
# std     86.775726     1.329497     0.400452     0.323938     0.154134
# min      0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     75.000000     0.000400     0.000000     0.020447     0.000000
# 50%    150.000000     0.547418     0.000000     0.161459     0.022237
# 75%    225.000000     1.302926     0.094992     0.452363     0.111559
# max    300.000000     5.000000     2.049814     1.583240     1.160190
#
#        AU06_r_mean  AU07_r_mean  AU09_r_mean  AU10_r_mean  AU12_r_mean  ...  \
# count   616.000000   616.000000   616.000000   616.000000   616.000000  ...
# mean      1.538014     1.456033     0.186504     1.201892     0.960946  ...
# std       0.587717     0.725682     0.265955     0.571336     0.523106  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       1.205749     1.071859     0.000000     0.726155     0.606792  ...
# 50%       1.594796     1.636537     0.042683     1.273910     0.981602  ...
# 75%       2.030503     1.993384     0.292016     1.673221     1.299921  ...
# max       2.644800     3.310010     1.264529     2.273780     2.232523  ...
#
#        AU14_r_std  AU15_r_std  AU17_r_std  AU20_r_std  AU23_r_std  AU25_r_std  \
# count  616.000000  616.000000  616.000000  616.000000  616.000000  616.000000
# mean     0.471978    0.205557    0.353407    0.129250    0.236271    0.434524
# std      0.355673    0.176805    0.265762    0.149580    0.219266    0.304130
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.221902    0.047281    0.183251    0.003764    0.031520    0.216889
# 50%      0.350843    0.171842    0.299895    0.087916    0.202460    0.393213
# 75%      0.647433    0.339851    0.463710    0.178331    0.387296    0.624531
# max      1.867494    0.987267    1.690420    0.870108    1.033640    1.378772
#
#        AU26_r_std  AU45_r_std  GoldStandardArousal  GoldStandardValence
# count  616.000000  616.000000           751.000000           751.000000
# mean     0.339594    0.362558            -0.062894             0.015042
# std      0.238619    0.370104             0.107319             0.073988
# min      0.000000    0.000000            -0.333236            -0.177328
# 25%      0.169709    0.001181            -0.150736            -0.028994
# 50%      0.313195    0.234348            -0.061569             0.019339
# 75%      0.504936    0.621231             0.020098             0.052672
# max      1.236286    1.487593             0.161764             0.336006
#
# [8 rows x 37 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

df_train = pd.read_csv('labels/emotion_zones/emotion_names/train_1.csv')
df_train['emotion_zone'].describe()
# Out:
# count      52507
# unique         4
# top       yellow
# freq       26397
# Name: emotion_zone, dtype: object

# %%
sns.catplot(x=df_train['emotion_zone'], kind="count", data=df_train);

# %%
df_train.groupby(['emotion_zone'])['frametime'].count()
