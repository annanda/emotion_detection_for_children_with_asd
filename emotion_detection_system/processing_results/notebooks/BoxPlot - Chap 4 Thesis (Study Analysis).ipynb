# %%
import os
import sys
import numpy as np
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt


from pylab import rcParams
# import matplotlib.animation as animation
# from matplotlib import rc

# configuration for graphics and random seed

# %matplotlib inline

# sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 7, 7

# %%
NOTEBOOK_DIR = os.path.dirname(os.path.realpath("__file__"))
PROJECT_ROOT = os.path.dirname(NOTEBOOK_DIR)

sys.path.append(PROJECT_ROOT) # make my_module available to import

# Importing my python module utils
from emotion_detection_system.processing_results.information_from_results import *

# %%
def does_it_pass_t_test(values_1, values_2,tolerance=0.05):
    _, pvalue = stats.ttest_ind(values_1, values_2)
    if pvalue <= tolerance:
        return True
    else:
        return False

# %%
# Getting only multimodal examples 
current_data = BASELINE_DATA
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
BASELINE_DATA = current_data

# %%
# Getting only multimodal examples 
current_data = oversampling_data_results
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
oversampling_data_results = current_data

# %%
# Getting only multimodal examples 
current_data = svm_undersampling_data_results
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
svm_undersampling_data_results = current_data

# %%
# Getting only multimodal examples 
current_data = nn_bl_data_results
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
nn_bl_data_results = current_data

# %%
# Getting only multimodal examples 
current_data = nn_oversampling_data_results
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
nn_oversampling_data_results = current_data

# %%
# Getting only multimodal examples 
current_data = nn_undersampling_data_results
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
nn_undersampling_data_results = current_data

# %%
current_data.shape[0]
# Out:
# 48

# %%
# Including a column to sign the Configuration Symbol
BASELINE_DATA['data_experiment_config'] = 'SVM_BL'
oversampling_data_results['data_experiment_config'] = 'SVM_OS'
svm_undersampling_data_results['data_experiment_config'] = 'SVM_US'
nn_bl_data_results['data_experiment_config'] = 'NN_BL'
nn_oversampling_data_results['data_experiment_config'] = 'NN_OS'
nn_undersampling_data_results['data_experiment_config'] = 'NN_US'

# %%
BASELINE_DATA
# Out:
#                 Data_Included_Slug     Participant        Session  \
# 2          all_data_va_late_fusion        All data            NaN
# 17        all_data_va_early_fusion        All data            NaN
# 50         all_data_va_late_fusion        All data            NaN
# 65        all_data_va_early_fusion        All data            NaN
# 1    participant_01_va_late_fusion  Participant_01            NaN
# 3    participant_02_va_late_fusion  Participant_02            NaN
# 6    participant_03_va_late_fusion  Participant_03            NaN
# 8    participant_04_va_late_fusion  Participant_04            NaN
# 11  participant_01_va_early_fusion  Participant_01            NaN
# 13  participant_04_va_early_fusion  Participant_04            NaN
# 29  participant_03_va_early_fusion  Participant_03            NaN
# 38  participant_02_va_early_fusion  Participant_02            NaN
# 49   participant_01_va_late_fusion  Participant_01            NaN
# ...

# %%
current_data = pd.concat([BASELINE_DATA, svm_undersampling_data_results, oversampling_data_results, 
                          nn_bl_data_results, nn_undersampling_data_results, nn_oversampling_data_results])
current_data
# Out:
#                Data_Included_Slug     Participant        Session  \
# 2         all_data_va_late_fusion        All data            NaN
# 17       all_data_va_early_fusion        All data            NaN
# 50        all_data_va_late_fusion        All data            NaN
# 65       all_data_va_early_fusion        All data            NaN
# 1   participant_01_va_late_fusion  Participant_01            NaN
# ..                            ...             ...            ...
# 71  session_01_01_va_early_fusion             NaN  Session_01_01
# 75   session_02_02_va_late_fusion             NaN  Session_02_02
# 81  session_03_01_va_early_fusion             NaN  Session_03_01
# 91  session_02_02_va_early_fusion             NaN  Session_02_02
# 93  session_04_01_va_early_fusion             NaN  Session_04_01
#
#            Scenario Annotation_Type  Accuracy  Accuracy_Balanced  \
# 2    va_late_fusion         parents    0.6508             0.4432
# ...

# %% [markdown]
# # Step 1 Plots

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
sns.set_style("whitegrid")
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="Accuracy",
                 width=0.3, palette=my_palette, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="Accuracy_Balanced", 
                 width=0.3, palette=my_palette,  showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Balanced Accuracy')
# Out:
# Text(0, 0.5, 'Balanced Accuracy')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
sns.set_style("whitegrid")
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="F1score_Blue",
                 width=0.3, palette=my_palette, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1score Blue')
# Out:
# Text(0, 0.5, 'F1score Blue')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
sns.set_style("whitegrid")
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="F1score_Green",
                 width=0.3, palette=my_palette, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1score Green')
# Out:
# Text(0, 0.5, 'F1score Green')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
sns.set_style("whitegrid")
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="F1score_Yellow",
                 width=0.3, palette=my_palette, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1score Yellow')
# Out:
# Text(0, 0.5, 'F1score Yellow')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
sns.set_style("whitegrid")
ax = sns.boxplot(data=current_data, x="data_experiment_config", y="F1score_Red",
                 width=0.3, palette=my_palette, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1score Red')
# Out:
# Text(0, 0.5, 'F1score Red')

# %%
nn_bl_data_results
# Out:
#                 Data_Included_Slug     Participant        Session  \
# 0         all_data_va_early_fusion        All data            NaN
# 14         all_data_va_late_fusion        All data            NaN
# 68         all_data_va_late_fusion        All data            NaN
# 70        all_data_va_early_fusion        All data            NaN
# 2    participant_04_va_late_fusion  Participant_04            NaN
# 5   participant_02_va_early_fusion  Participant_02            NaN
# 6    participant_03_va_late_fusion  Participant_03            NaN
# 7    participant_02_va_late_fusion  Participant_02            NaN
# 10   participant_01_va_late_fusion  Participant_01            NaN
# 15  participant_03_va_early_fusion  Participant_03            NaN
# 41  participant_01_va_early_fusion  Participant_01            NaN
# 42  participant_04_va_early_fusion  Participant_04            NaN
# 48   participant_01_va_late_fusion  Participant_01            NaN
# ...

# %%
nn_oversampling_data_results
# Out:
#                 Data_Included_Slug     Participant        Session  \
# 10         all_data_va_late_fusion        All data            NaN
# 14        all_data_va_early_fusion        All data            NaN
# 63        all_data_va_early_fusion        All data            NaN
# 92         all_data_va_late_fusion        All data            NaN
# 11  participant_01_va_early_fusion  Participant_01            NaN
# 16  participant_04_va_early_fusion  Participant_04            NaN
# 26   participant_02_va_late_fusion  Participant_02            NaN
# 27   participant_03_va_late_fusion  Participant_03            NaN
# 33   participant_01_va_late_fusion  Participant_01            NaN
# 36  participant_02_va_early_fusion  Participant_02            NaN
# 39   participant_04_va_late_fusion  Participant_04            NaN
# 47  participant_03_va_early_fusion  Participant_03            NaN
# 58  participant_01_va_early_fusion  Participant_01            NaN
# ...

# %%
nn_bl_data_results['model_group'] = nn_bl_data_results.apply(lambda row: get_model_group(row), axis=1)
nn_oversampling_data_results['model_group'] = nn_oversampling_data_results.apply(lambda row: get_model_group(row), 
                                                                                 axis=1)
nn_bl_data_results
# Out:
#                 Data_Included_Slug     Participant        Session  \
# 0         all_data_va_early_fusion        All data            NaN
# 14         all_data_va_late_fusion        All data            NaN
# 68         all_data_va_late_fusion        All data            NaN
# 70        all_data_va_early_fusion        All data            NaN
# 2    participant_04_va_late_fusion  Participant_04            NaN
# 5   participant_02_va_early_fusion  Participant_02            NaN
# 6    participant_03_va_late_fusion  Participant_03            NaN
# 7    participant_02_va_late_fusion  Participant_02            NaN
# 10   participant_01_va_late_fusion  Participant_01            NaN
# 15  participant_03_va_early_fusion  Participant_03            NaN
# 41  participant_01_va_early_fusion  Participant_01            NaN
# 42  participant_04_va_early_fusion  Participant_04            NaN
# 48   participant_01_va_late_fusion  Participant_01            NaN
# ...

# %% [markdown]
# # Step 2 Plots

# %%
step_2_data = pd.concat([nn_bl_data_results, nn_oversampling_data_results])
step_2_data
# Out:
#                Data_Included_Slug     Participant        Session  \
# 0        all_data_va_early_fusion        All data            NaN
# 14        all_data_va_late_fusion        All data            NaN
# 68        all_data_va_late_fusion        All data            NaN
# 70       all_data_va_early_fusion        All data            NaN
# 2   participant_04_va_late_fusion  Participant_04            NaN
# ..                            ...             ...            ...
# 71  session_01_01_va_early_fusion             NaN  Session_01_01
# 75   session_02_02_va_late_fusion             NaN  Session_02_02
# 81  session_03_01_va_early_fusion             NaN  Session_03_01
# 91  session_02_02_va_early_fusion             NaN  Session_02_02
# 93  session_04_01_va_early_fusion             NaN  Session_04_01
#
#            Scenario Annotation_Type  Accuracy  Accuracy_Balanced  \
# 0   va_early_fusion         parents    0.7503             0.6557
# ...

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="Accuracy", 
                 hue='model_group', hue_order = hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.5,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
my_palette = {'SVM_BL': '#FFF0F5', 'SVM_US': '#FFD1DA', 'SVM_OS': '#FBA1B7',
             'NN_OS': '#4CC9F0', 'NN_US': '#8BE8E5', 'NN_BL': '#D5FFE4' }
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="Accuracy_Balanced", 
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.5,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Balanced Accuracy')
# Out:
# Text(0, 0.5, 'Balanced Accuracy')

# %%
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="F1score_Blue", 
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.5,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1Scores Blue')
# Out:
# Text(0, 0.5, 'F1Scores Blue')

# %%
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="F1score_Green", 
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.5,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1Scores Green')
# Out:
# Text(0, 0.5, 'F1Scores Green')

# %%
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="F1score_Yellow", 
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.5,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1Scores Yellow')
# Out:
# Text(0, 0.5, 'F1Scores Yellow')

# %%
hue_order = ['GM', 'PSM', 'SSM']
sns.set_style("whitegrid")
ax = sns.boxplot(data=step_2_data, x="data_experiment_config", y="F1score_Red", 
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0.3,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('F1Scores Red')
# Out:
# Text(0, 0.5, 'F1Scores Red')

# %% [markdown]
# # Oversampling Random vs. Oversampling Adasyn (NN)

# %%
# Getting only multimodal examples 
current_data = nn_oversampling_adasyn
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
bl_all , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='all_data')
bl_p , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='participants')
bl_s , _ = get_subset_data(current_data, 
                scenario=scenario,
                annotation_type=annotation_type, 
                subdataset_case='sessions')
current_data = pd.concat([bl_all, bl_p, bl_s])
nn_oversampling_adasyn = current_data


nn_oversampling_adasyn['data_experiment_config'] = 'NN_OS_Adasyn'
nn_oversampling_data_results['model_group'] = nn_oversampling_data_results.apply(lambda row: get_model_group(row), axis=1)
nn_oversampling_adasyn['model_group'] = nn_oversampling_adasyn.apply(lambda row: get_model_group(row), axis=1)

oversamplings = pd.concat([nn_oversampling_adasyn, nn_oversampling_data_results])
oversamplings
# Out:
#                 Data_Included_Slug     Participant        Session  \
# 27         all_data_va_late_fusion        All data            NaN
# 38        all_data_va_early_fusion        All data            NaN
# 50        all_data_va_early_fusion        All data            NaN
# 89         all_data_va_late_fusion        All data            NaN
# 3   participant_02_va_early_fusion  Participant_02            NaN
# ..                             ...             ...            ...
# 71   session_01_01_va_early_fusion             NaN  Session_01_01
# 75    session_02_02_va_late_fusion             NaN  Session_02_02
# 81   session_03_01_va_early_fusion             NaN  Session_03_01
# 91   session_02_02_va_early_fusion             NaN  Session_02_02
# 93   session_04_01_va_early_fusion             NaN  Session_04_01
#
#            Scenario Annotation_Type  Accuracy  Accuracy_Balanced  \
# 27   va_late_fusion         parents    0.7375             0.6828
# ...

# %%
hue_order = ['GM', 'PSM', 'SSM']
order_x = ['NN_OS', 'NN_OS_Adasyn']
sns.set_style("whitegrid")
ax = sns.boxplot(data=oversamplings, x="data_experiment_config", y="Accuracy", 
                 order=order_x,
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
hue_order = ['GM', 'PSM', 'SSM']
order_x = ['NN_OS', 'NN_OS_Adasyn']
sns.set_style("whitegrid")
ax = sns.boxplot(data=oversamplings, x="data_experiment_config", y="Accuracy_Balanced", 
                 order=order_x,
                 hue='model_group', hue_order=hue_order,
                 width=0.3, showmeans=True, 
                 meanprops={'marker':'o',
                       'markerfacecolor':'orange', 
                       'markeredgecolor':'black',
                       'markersize':'8'})
ax.set(ylim=(0,1))
ax.set_xlabel('Data Experiment Configuration')
ax.set_ylabel('Balanced Accuracy')
# Out:
# Text(0, 0.5, 'Balanced Accuracy')

# %% [markdown]
# # Step 3 Analysis - Modalities, Fusion Type and Annotation type

# %%
scenario=['va_late_fusion', 'va_early_fusion', 'a', 'v']
annotation_type=['parents', 'specialist']
subset_data='all_data'
resulting_df, _ = get_subset_data(nn_oversampling_data_results, 
                                            scenario=scenario,
                                            annotation_type=annotation_type, 
                                            subdataset_case=subset_data)
# Creating a new column with Modality
new_column = pd.DataFrame(columns=['Modality'])
new_column['Modality'] = resulting_df.apply(lambda row: get_modality(row), axis=1)
resulting_df = pd.concat([resulting_df, new_column], axis=1)

step_3_data_gm = resulting_df

step_3_data_gm
# Out:
#           Data_Included_Slug Participant Session         Scenario  \
# 5                 all_data_a    All data     NaN                a
# 10   all_data_va_late_fusion    All data     NaN   va_late_fusion
# 14  all_data_va_early_fusion    All data     NaN  va_early_fusion
# 44                all_data_v    All data     NaN                v
# 49                all_data_a    All data     NaN                a
# 63  all_data_va_early_fusion    All data     NaN  va_early_fusion
# 86                all_data_v    All data     NaN                v
# 92   all_data_va_late_fusion    All data     NaN   va_late_fusion
#
#    Annotation_Type  Accuracy  Accuracy_Balanced  Precision_Blue  \
# 5          parents    0.3592             0.3337          0.3021
# 10         parents    0.7362             0.6964          0.7298
# 14         parents    0.7380             0.6764          0.6858
# 44         parents    0.7425             0.7117          0.7173
# ...

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="Accuracy", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('Accuracy')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="Accuracy_Balanced", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('Balanced Accuracy')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="F1score_Blue", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('F1Scores Blue')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="F1score_Green", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('F1Scores Green')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="F1score_Yellow", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('F1Scores Yellow')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %%
order_x = ['a', 'v', 'Multimodal']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_gm, x="Modality", y="F1score_Red", 
                    order = order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Modalities')
ax.set_ylabel('F1Scores Red')
ax.set_xticks([0, 1, 2], ['Audio', 'Video', 'Multimodal'])

# %% [markdown]
# # Plots Step 3 - Fusion Type

# %%
scenario=['va_late_fusion', 'va_early_fusion']
annotation_type=['parents', 'specialist']
subset_data='all_data'
resulting_df, _ = get_subset_data(nn_oversampling_data_results, 
                                            scenario=scenario,
                                            annotation_type=annotation_type, 
                                            subdataset_case=subset_data)
# Creating a new column with Modality
# new_column = pd.DataFrame(columns=['Modality'])
# new_column['Modality'] = resulting_df.apply(lambda row: get_modality(row), axis=1)
# resulting_df = pd.concat([resulting_df, new_column], axis=1)

step_3_data_fusion = resulting_df

step_3_data_fusion
# Out:
#           Data_Included_Slug Participant Session         Scenario  \
# 10   all_data_va_late_fusion    All data     NaN   va_late_fusion
# 14  all_data_va_early_fusion    All data     NaN  va_early_fusion
# 63  all_data_va_early_fusion    All data     NaN  va_early_fusion
# 92   all_data_va_late_fusion    All data     NaN   va_late_fusion
#
#    Annotation_Type  Accuracy  Accuracy_Balanced  Precision_Blue  \
# 10         parents    0.7362             0.6964          0.7298
# 14         parents    0.7380             0.6764          0.6858
# 63      specialist    0.7961             0.7037          0.6824
# 92      specialist    0.8070             0.7273          0.7279
#
#     Precision_Green  Precision_Red  Precision_Yellow  Recall_Blue  \
# 10           0.8406         0.5271            0.5514       0.7120
# 14           0.8204         0.5476            0.6173       0.7502
# 63           0.8767         0.5583            0.6795       0.7607
# ...

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="Accuracy", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('Accuracy')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="Accuracy_Balanced", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('Balanced Accuracy')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="F1score_Blue", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('F1Scores Blue')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="F1score_Green", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('F1Scores Green')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="F1score_Yellow", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('F1Scores Yellow')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %%
order_x = ['va_early_fusion', 'va_late_fusion']
sns.set_style("whitegrid")
ax = sns.stripplot(data=step_3_data_fusion, x="Scenario", y="F1score_Red", 
                   order=order_x,
                    color = 'black', jitter=False)
ax.set(ylim=(0,1))
ax.set_xlabel('Fusion Technique')
ax.set_ylabel('F1Scores Red')
ax.set_xticks([0, 1], ['Late Fusion', 'Early Fusion'])

# %% [markdown]
# # Plots Step 3 - Annotation Type
